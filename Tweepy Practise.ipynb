# %%
import tweepy

# %%
from tweepy import Stream
from tweepy import OAuthHandler
from tweepy.streaming import StreamListener
import time
import json
from html.parser import HTMLParser

# %% [markdown]
# Define the 4 important items needed to access twitter feed: 1) customer key (ckey), 2) customer secret (csecret), 3) access token (atoken) and 4) access secret (asecret).

# %%
ckey = 'KgMotZ0G6pCUtqs7QeJDdOaWq'
csecret = 't8jxflESIzxy6ECVXl4Evo0BjjMEJhQUyYRH3JW8b9qeDekAxW'
atoken = '1074143720235327489-JWn1h8dhPbjCVZzCR3qcn1hSfRx0fi'
asecret = 'DaEhyVpwkPKK75rMsQFu00f0N5ANsAA6oMXzbVmx1vqFX'

# %%
class listener(StreamListener):
    def on_data(self, data):
        try:
            print (data)
            #Printing data returns all unncessary infomration. We need only tweet texts and a time stamp.
            tweet = data.split(',"text":"')[1].split('","source":')[0]
            print(tweet)
            #include timestamp
            TrimData = str(time.time())+'::'+tweet
            saveFile = open('sampletweets2.csv','a')
            saveFile.write(TrimData)
            saveFile.write('\n')
            saveFile.close()               
            return True
        except BaseException as e:
            print('failed ondata,',str(e))
            time.sleep(5)
    
    def on_error(self, status):
        print (status)
        
auth = OAuthHandler(ckey, csecret)
auth.set_access_token(atoken, asecret)
twitterStream = Stream(auth, listener())
twitterStream.filter(track=["senate"])
# Out:
# {"created_at":"Sun Dec 16 20:55:03 +0000 2018","id":1074407582658424832,"id_str":"1074407582658424832","text":"RT @SenatorHousakos: Trudeau's Senate is costing taxpayers tens of millions of dollars more because it costs more to fund 4 caucuses than i\u2026","source":"\u003ca href=\"http:\/\/twitter.com\/download\/android\" rel=\"nofollow\"\u003eTwitter for Android\u003c\/a\u003e","truncated":false,"in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":null,"in_reply_to_user_id_str":null,"in_reply_to_screen_name":null,"user":{"id":178830272,"id_str":"178830272","name":"James Bountrogiannis","screen_name":"SpeakeasyJames","location":"GTA, Ontario, Canada","url":null,"description":"60 yr old Christian man, father of amazing son & apple-of-my-eye daughter. Opinions are my own. Retweets are not necessarily agreements. #CONSERVATIVE","translator_type":"none","protected":false,"verified":false,"followers_count":6062,"friends_count":6028,"listed_count":104,"favou
# ...
